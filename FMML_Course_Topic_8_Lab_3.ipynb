# %% [markdown]
# <a href="https://colab.research.google.com/github/madhuribheemarati/FMML-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 15:19:04--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  82.0MB/s    in 0.8s
#
# 2024-03-27 15:19:06 (82.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14811   0909.3028v1  Handwriting is an alternative method for enter...    cs
# 21536   0912.1618v1  In this paper, we consider the problem of "hyp...  stat
# 2468   1612.00767v2  We consider parallel asynchronous Markov Chain...  stat
# 5845    1206.6449v1  Bayesian reinforcement learning (BRL) encodes ...    cs
# 13899  1605.01855v1  This research is focused on solving problems i...    cs
# ...             ...                                                ...   ...
# 12104  1708.05357v2  We propose a generic algorithmic building bloc...    cs
# 8996    1411.1243v1  Twitter has been proven to be a notable source...  stat
# 3125    1308.3101v2  Label assignment problems with large state spa...    cs
# 25010  1501.07692v1  This paper presents a novel method for identif...    cs
# 37849   0811.4167v3  We propose a penalized orthogonal-components r...  stat
#
#                                                    title  year  \
# 14811  Vers la reconnaissance de mini-messages manusc...  2009
# 21536                   Hyper-sparse optimal aggregation  2009
# 2468   Asynchronous Stochastic Gradient MCMC with Ela...  2016
# 5845         Monte Carlo Bayesian Reinforcement Learning  2012
# 13899     Resource allocation using metaheuristic search  2016
# ...                                                  ...   ...
# 12104  Efficient Use of Limited-Memory Accelerators f...  2017
# 8996          Using Twitter to predict football outcomes  2014
# 3125   Compact Relaxations for MAP Inference in Pairw...  2013
# 25010  Blob indentation identification via curvature ...  2015
# 37849  Penalized Orthogonal-Components Regression for...  2008
#
#                                                 keywords
# 14811  [handwriting, alternative, abbreviations, cons...
# 21536  [aggregation, dictionary, functions, aggregati...
# 2468   [asynchronous, gradients, continuous, distribu...
# 5845   [reinforcement, knowledge, represents, uncerta...
# 13899  [management, metaheuristic, algorithms, engine...
# ...                                                  ...
# 12104  [algorithmic, accelerate, heterogeneous, effic...
# 8996   [predictive, modelling, dissemination, conduct...
# 3125   [assignment, important, especially, interactio...
# 25010  [identifying, indentations, curvature, indenta...
# 37849  [penalized, orthogonal, components, regression...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14811    [handwriting, alternative, abbreviations, cons...
# 21536    [aggregation, dictionary, functions, aggregati...
# 2468     [asynchronous, gradients, continuous, distribu...
# 5845     [reinforcement, knowledge, represents, uncerta...
# 13899    [management, metaheuristic, algorithms, engine...
#                                ...
# 15292    [morphologically, maharashtra, development, st...
# 8837     [selection, coherence, generation, multimedia,...
# 11179    [establishes, consistency, algorithms, cluster...
# 12231    [algorithm, optimization, curvature, increment...
# 20178    [ontological, representation, reasoning, inter...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8776 words.
# Out of those 4522 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9359ae11-b79f-451b-9bb7-7820c32d0c26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9359ae11-b79f-451b-9bb7-7820c32d0c26")) {                    Plotly.newPlot(                        "9359ae11-b79f-451b-9bb7-7820c32d0c26",                        [{"x":["processed","significant","handwritten","alternative","challenging","collected","specifically","abbreviations","recognition","reconnaissance","consonant","phenomena","handwriting","consonantal","strategies","different","construction","situations","previously","suboptimal","regression","selection","parameter","coefficients","selectors","algorithm","particular","simulated","functions","procedures","aggregation","irrelevant","inequality","dictionary","anisotropic","regularization","adaptation","hamiltonian","gradients","parallelization","experiments","empirically","resulting","sequential","exploration","stochastic","inherently","asynchronous","continuous","instances","significantly","distribution","algorithms","theoretical","observable","reinforcement","relatively","distributions","represents","approximation","underlying","conjugate","approximates","experimental","hypotheses","partially","guaranteed","maintaining","parameters","naturally","representation","uncertainty","knowledge","performance","probability","metaheuristic","performed","management","comparative","engineering","annealing","development","techniques","allocation","scheduling","metaheuristics","ensembling","improving","generators","deconvolutional","stability","generative","discriminator","adversarial","collapsing","suggested","generator","oscillating","converging","difficult","architecture","additionally","environments","complexity","induction","dependent","algorithmic","universal","solomonoff","intelligent","kolmogorov","invariance","information","intelligence","universally","properties","drastically","computable","subjective","optimality","consistent","advantage","extension","efficiency","represent","judgments","uniformity","measuring","densities","similarity","adjustable","considered","separated","computing","computational","computation","intuitive","successfully","therefore","irregular","experiment","considers","compensation","correlation","benchmark","derivations","explanation","introduce","generalized","inspection","maintenance","detection","extractor","structures","automatic","evaluation","comprehensive","descriptors","classifier","necessary","resolution","candidates","processing","evaluating","supervised","unacceptably","dimensional","unsupervised","interpretable","entailment","introduces","unlabeled","embeddings","vocabularies","implement","distributional","evaluations","important","addressed","embedding","answering","coreference","discovery","generalization","precision","inclusion","literature","hypernymy","extraction","correlations","relations","comparable","leveraging","incorporated","predictive","statistics","capturing","competitive","demonstrates","thousands"],"y":[30,266,22,106,280,90,192,3,385,2,4,33,8,3,93,728,73,45,93,12,125,187,125,38,0,814,275,78,223,30,30,17,8,55,10,76,58,3,40,1,625,61,157,65,51,126,18,14,94,91,243,209,610,141,18,110,51,119,50,105,109,7,7,384,27,53,29,43,251,60,364,77,352,875,177,6,123,40,47,50,7,141,391,34,23,7,3,110,5,3,36,101,11,96,1,24,21,1,4,156,248,61,90,226,19,77,39,30,2,64,4,23,669,93,3,212,18,13,24,28,67,87,68,158,114,15,2,31,8,142,4,120,10,137,296,161,39,91,152,11,73,39,5,71,219,5,20,331,70,10,13,345,11,133,194,251,72,50,148,81,128,22,325,66,187,3,210,126,33,17,60,40,81,4,79,24,52,362,40,116,48,8,53,97,77,10,126,4,137,25,101,97,37,28,54,53,44,120,64,26],"type":"bar"},{"x":["processed","significant","handwritten","alternative","challenging","collected","specifi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4522,), (4522, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>in</span> <span style=''>SMT</span> <span style=''>with</span> <span style=''>LA(Q)</span> <span style=''>Cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>contexts</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4794520547945205);'>automated</span> <span style='background-color:rgba(0, 255, 0, 0.821917808219178);'>reasoning</span> <span style=''>and</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.8857142857142857);'>verification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>decision</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3254437869822486);'>effectively</span> <span style=''>encoded</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Satisfiability</span> <span style=''>Modulo</span> <span style=''>Theories</span> <span style=''>(SMT)</span> <span style=''>In</span> <span style=''>the</span> <span style=''>last</span> <span style=''>decade</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>SMT</span> <span style=''>solvers</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>several</span> <span style=''>theories</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>interest</span> <span style=''>(eg</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>arithmetic</span> <span style=''>arrays</span> <span style=''>bit</span> <span style=''>vectors)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Surprisingly</span> <span style=''>very</span> <span style=''>few</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>SMT</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>are</span> <span style=''>not</span> <span style=''>aware</span> <span style=''>of</span> <span style=''>any</span> <span style=''>work</span> <span style=''>on</span> <span style=''>SMT</span> <span style=''>solvers</span> <span style=''>able</span> <span style=''>to</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.35964912280701744);'>solutions</span> <span style=''>which</span> <span style=''>minimize</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>over</span> <span style=''>arithmetical</span> <span style='background-color:rgba(255, 0, 0, 0.40092165898617516);'>variables</span> <span style=''>This</span> <span style=''>is</span> <span style=''>unfortunate</span> <span style=''>since</span> <span style=''>some</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>require</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>functionality</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>start</span> <span style=''>filling</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>We</span> <span style=''>present</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>two</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Weighted</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <span style=''>with</span> <span style=''>Partial</span> <span style=''>Data</span> <br/><br/><span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>popular</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>given</span> <span style=''>only</span> <span style=''>lower</span> <span style=''>order</span> <span style=''>moments</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>However</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>that</span> <span style=''>we</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>data</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>these</span> <span style=''>moments</span> <span style=''>to</span> <span style=''>high</span> <span style=''>accuracy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>case</span> <span style=''>in</span> <span style=''>which</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>not</span> <span style=''>always</span> <span style=''>observed</span> <span style=''>common</span> <span style=''>in</span> <span style=''>applied</span> <span style=''>settings</span> <span style=''>where</span> <span style=''>not</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>may</span> <span style=''>be</span> <span style=''>taken</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>moment</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>varying</span> <span style=''>quality</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>weighted</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>as</span> <span style=''>the</span> <span style=''>non</span> <span style=''>weighted</span> <span style=''>approach</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>do</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriately</span> <span style=''>leverage</span> <span style=''>these</span> <span style=''>less</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimen ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.8400000000000001);'>Identifiability</span> <span style=''>of</span> <span style=''>Causal</span> <span style=''>Graphs</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3035714285714286);'>Functional</span> <span style=''>Models</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>addresses</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>question</span> <span style=''>Under</span> <span style=''>what</span> <span style='background-color:rgba(255, 0, 0, 0.4534883720930233);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3413173652694611);'>generating</span> <span style=''>process</span> <span style=''>can</span> <span style=''>one</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>graph</span> <span style=''>from</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>taken</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>based</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>methods</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.4534883720930233);'>assumptions</span> <span style=''>the</span> <span style=''>Markov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>faithfulness</span> <span style=''>It</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>under</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.4534883720930233);'>assumptions</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>graph</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style=''>up</span> <span style=''>to</span> <span style=''>Markov</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>(some</span> <span style=''>arrows</span> <span style=''>remain</span> <span style=''>undirected)</span> <span style=''>using</span> <span style=''>methods</span> <span style=''>like</span> <span style=''>the</span> <span style=''>PC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>by</span> <span style=''>defining</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>Identifiable</span> <span style='background-color:rgba(255, 0, 0, 0.3035714285714286);'>Functional</span> <span style=''>Model</span> <span style=''>Classes</span> <span style=''>(IFMOCs)</span> <span style=''>As</span> <span style=''>our</span> <span style=''>main</span> <span style=''>theorem</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3413173652694611);'>generating</span> <span style=''>process</span> <span style=''>belongs ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Plea</span> <span style=''>for</span> <span style=''>Neutral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparison</span> <span style=''>Studies</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>Sciences</span> <br/><br/><span style=''>In</span> <span style=''>a</span> <span style=''>context</span> <span style=''>where</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>articles</span> <span style=''>are</span> <span style=''>devoted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>new</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>studies</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appreciated</span> <span style=''>by</span> <span style=''>readers</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>given</span> <span style=''>poor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consideration</span> <span style=''>by</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style=''>journals</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>recent</span> <span style=''>articles</span> <span style=''>on</span> <span style=''>over</span> <span style=''>optimism</span> <span style=''>and</span> <span style=''>epistemology</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bioinformatics</span> <span style=''>this</span> <span style=''>letter</span> <span style=''>stresses</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>neutral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>studies</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishment</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>standards</span> <span style=''>by</span> <span style=''>drawing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parallels</span> <span style=''>with</span> <span style=''>clinical</span> <span style=''>research</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12912380276693863)
# 	architecture (0.08797445902802412)
# 	experimental (0.1362185172046825)
# 	segmentation (0.07378503015253636)
# 	information (0.2373181979425328)
# 	different (0.25824760553387727)
# 	processing (0.11528910961333806)
# 	detection (0.12238382405108195)
# 	convolutional (0.13728272437034408)
# 	recognition (0.13657325292656972)
#
# Some Statistics words are:
# 	stochastic (0.1352852094901565)
# 	algorithm (0.38162544169611307)
# 	theoretical (0.15093387178192832)
# 	distribution (0.17566885411408378)
# 	variables (0.1534578495709238)
# 	statistical (0.17213528520949015)
# 	estimation (0.19081272084805653)
# 	dimensional (0.19636547198384655)
# 	inference (0.20242301867743565)
# 	regression (0.18374558303886926)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bcc643ad-479b-4cf2-8a5c-891cc09b0044" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcc643ad-479b-4cf2-8a5c-891cc09b0044")) {                    Plotly.newPlot(                        "bcc643ad-479b-4cf2-8a5c-891cc09b0044",                        [{"x":["processed","significant","handwritten","alternative","challenging","collected","specifically","abbreviations","recognition","reconnaissance","consonant","phenomena","handwriting","consonantal","strategies","different","construction","situations","previously","suboptimal","regression","selection","parameter","coefficients","selectors","algorithm","particular","simulated","functions","procedures","aggregation","irrelevant","inequality","dictionary","anisotropic","regularization","adaptation","hamiltonian","gradients","parallelization","experiments","empirically","resulting","sequential","exploration","stochastic","inherently","asynchronous","continuous","instances","significantly","distribution","algorithms","theoretical","observable","reinforcement","relatively","distributions","represents","approximation","underlying","conjugate","approximates","experimental","hypotheses","partially","guaranteed","maintaining","parameters","naturally","representation","uncertainty","knowledge","performance","probability","metaheuristic","performed","management","comparative","engineering","annealing","development","techniques","allocation","scheduling","metaheuristics","ensembling","improving","generators","deconvolutional","stability","generative","discriminator","adversarial","collapsing","suggested","generator","oscillating","converging","difficult","architecture","additionally","environments","complexity","induction","dependent","algorithmic","universal","solomonoff","intelligent","kolmogorov","invariance","information","intelligence","universally","properties","drastically","computable","subjective","optimality","consistent","advantage","extension","efficiency","represent","judgments","uniformity","measuring","densities","similarity","adjustable","considered","separated","computing","computational","computation","intuitive","successfully","therefore","irregular","experiment","considers","compensation","correlation","benchmark","derivations","explanation","introduce","generalized","inspection","maintenance","detection","extractor","structures","automatic","evaluation","comprehensive","descriptors","classifier","necessary","resolution","candidates","processing","evaluating","supervised","unacceptably","dimensional","unsupervised","interpretable","entailment","introduces","unlabeled","embeddings","vocabularies","implement","distributional","evaluations","important","addressed","embedding","answering","coreference","discovery","generalization","precision","inclusion","literature","hypernymy","extraction","correlations","relations","comparable","leveraging","incorporated","predictive","statistics","capturing","competitive","demonstrates","thousands","characterization","estimates","prototype","signatures","estimation","monitoring","effective","estimated","individuals","formulates","comparison","characterize","applications","construct","implements","hoeffding","developed","application","approaches","predicting","classifiers","reservoir","outperforming","indicators","currently","evolution","intuitively","framework","incorporate","classification","observation","violations","detectors","characteristics","accurately","detecting","distances","performances","comparing","semiparametric","procedure","investigate","empirical","numerical","divergence","parametric","estimator","asymptotic","exploited","homogeneity","illustrate","inference","likelihood","covariance","subspaces","concerned","percen ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	selectors
# 	determinant
# 	therapies
# 	stimulated
# 	lookahead
# 	inordinately
# 	emphsparse
# 	integrals
# 	psychiatric
# 	comorbidity
# 	suppressing
# 	predictivity
# 	distinguishable
# 	generically
# 	sacrifice
# 	tsybakovs
# 	noiseless
# 	insurance
# 	substantiate
# 	blockmodel
# Some words which never appear in Statistics papers:
# 	abbreviations
# 	reconnaissance
# 	consonant
# 	consonantal
# 	metaheuristic
# 	metaheuristics
# 	solomonoff
# 	compensation
# 	unacceptably
# 	entailment
# 	coreference
# 	hypernymy
# 	travelling
# 	apartment
# 	television
# 	navigating
# 	autonomously
# 	localizing
# 	grounding
# 	axiomatization

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0569821472242604e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
